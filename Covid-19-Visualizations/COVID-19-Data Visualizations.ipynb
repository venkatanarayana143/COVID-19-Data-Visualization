# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
df = pd.read_csv('patient.csv')
df
# Out:
#         id     sex  birth_year country               region group  \
# 0        1  female      1984.0   China  filtered at airport   NaN
# 1        2    male      1964.0   Korea  filtered at airport   NaN
# 2        3    male      1966.0   Korea         capital area   NaN
# 3        4    male      1964.0   Korea         capital area   NaN
# 4        5    male      1987.0   Korea         capital area   NaN
# 5        6    male      1964.0   Korea         capital area   NaN
# 6        7    male      1991.0   Korea         capital area   NaN
# 7        8  female      1957.0   Korea         Jeollabuk-do   NaN
# 8        9  female      1992.0   Korea         capital area   NaN
# 9       10  female      1966.0   Korea         capital area   NaN
# 10      11    male      1995.0   Korea         capital area   NaN
# 11      12    male      1971.0   China         capital area   NaN
# 12      13    male      1992.0   Korea  filtered at airport   NaN
# 13      14  female      1980.0   China         capital area   NaN
# 14      15    male      1977.0   Korea         capital area   NaN
# 15      16  female      1977.0   Korea              Gwangju   NaN
# 16      17    male      1982.0   Korea         capital area   NaN
# 17      18  female      1999.0   Korea              Gwangju   NaN
# 18      19    male      1983.0   Korea         capital area   NaN
# 19      20  female      1978.0   Korea         capital area   NaN
# 20      21  female      1960.0   Korea         capital area   NaN
# 21      22    male      1973.0   Korea              Gwangju   NaN
# 22      23  female      1962.0   China         capital area   NaN
# 23      24    male      1992.0   Korea  filtered at airport   NaN
# 24      25  female      1946.0   Korea         capital area   NaN
# 25      26    male      1968.0   Korea         capital area   NaN
# 26      27  female      1982.0   China         capital area   NaN
# 27      28  female      1989.0   China         capital area   NaN
# 28      29    male      1938.0   Korea         capital area   NaN
# 29      30  female      1952.0   Korea         capital area   NaN
# ...    ...     ...         ...     ...                  ...   ...
# 5298  5299     NaN         NaN   Korea                  NaN   NaN
# 5299  5300     NaN         NaN   Korea                  NaN   NaN
# 5300  5301     NaN         NaN   Korea                  NaN   NaN
# 5301  5302     NaN         NaN   Korea                  NaN   NaN
# 5302  5303     NaN         NaN   Korea                  NaN   NaN
# 5303  5304     NaN         NaN   Korea                  NaN   NaN
# 5304  5305     NaN         NaN   Korea                  NaN   NaN
# 5305  5306     NaN         NaN   Korea                  NaN   NaN
# 5306  5307     NaN         NaN   Korea                  NaN   NaN
# 5307  5308     NaN         NaN   Korea                  NaN   NaN
# 5308  5309     NaN         NaN   Korea                  NaN   NaN
# 5309  5310     NaN         NaN   Korea                  NaN   NaN
# 5310  5311     NaN         NaN   Korea                  NaN   NaN
# 5311  5312     NaN         NaN   Korea                  NaN   NaN
# 5312  5313     NaN         NaN   Korea                  NaN   NaN
# 5313  5314     NaN         NaN   Korea                  NaN   NaN
# 5314  5315     NaN         NaN   Korea                  NaN   NaN
# 5315  5316     NaN         NaN   Korea                  NaN   NaN
# 5316  5317     NaN         NaN   Korea                  NaN   NaN
# 5317  5318     NaN         NaN   Korea                  NaN   NaN
# 5318  5319     NaN         NaN   Korea                  NaN   NaN
# 5319  5320     NaN         NaN   Korea                  NaN   NaN
# 5320  5321     NaN         NaN   Korea                  NaN   NaN
# 5321  5322     NaN         NaN   Korea                  NaN   NaN
# 5322  5323     NaN         NaN   Korea                  NaN   NaN
# 5323  5324     NaN         NaN   Korea                  NaN   NaN
# 5324  5325     NaN         NaN   Korea                  NaN   NaN
# 5325  5326     NaN         NaN   Korea                  NaN   NaN
# 5326  5327     NaN         NaN   Korea                  NaN   NaN
# 5327  5328     NaN         NaN   Korea                  NaN   NaN
#
#                        infection_reason  infection_order  infected_by  \
# 0                        visit to Wuhan              1.0          NaN
# 1                        visit to Wuhan              1.0          NaN
# 2                        visit to Wuhan              1.0          NaN
# 3                        visit to Wuhan              1.0          NaN
# 4                        visit to Wuhan              1.0          NaN
# 5                  contact with patient              2.0          3.0
# 6                        visit to Wuhan              1.0          NaN
# 7                        visit to Wuhan              1.0          NaN
# 8                  contact with patient              2.0          5.0
# 9                  contact with patient              3.0          6.0
# 10                 contact with patient              3.0          6.0
# 11        contact with patient in Japan              2.0          NaN
# 12                   residence in Wuhan              1.0          NaN
# 13                 contact with patient              3.0         12.0
# 14                 contact with patient              2.0          4.0
# 15                    visit to Thailand              1.0          NaN
# 16    contact with patient in Singapore              2.0          NaN
# 17                 contact with patient              2.0         16.0
# 18    contact with patient in Singapore              2.0          NaN
# 19                 contact with patient              3.0         15.0
# 20                 contact with patient              3.0          6.0
# 21                 contact with patient              2.0         16.0
# 22                       visit to Wuhan              1.0          NaN
# 23                   residence in Wuhan              1.0          NaN
# 24                 contact with patient              2.0         27.0
# 25                 contact with patient              1.0         27.0
# 26                       visit to China              1.0          NaN
# 27                 contact with patient              2.0          3.0
# 28                 contact with patient              4.0         83.0
# 29                 contact with patient              5.0         29.0
# ...                                 ...              ...          ...
# 5298                                NaN              NaN          NaN
# 5299                                NaN              NaN          NaN
# 5300                                NaN              NaN          NaN
# 5301                                NaN              NaN          NaN
# 5302                                NaN              NaN          NaN
# 5303                                NaN              NaN          NaN
# 5304                                NaN              NaN          NaN
# 5305                                NaN              NaN          NaN
# 5306                                NaN              NaN          NaN
# 5307                                NaN              NaN          NaN
# 5308                                NaN              NaN          NaN
# 5309                                NaN              NaN          NaN
# 5310                                NaN              NaN          NaN
# 5311                                NaN              NaN          NaN
# 5312                                NaN              NaN          NaN
# 5313                                NaN              NaN          NaN
# 5314                                NaN              NaN          NaN
# 5315                                NaN              NaN          NaN
# 5316                                NaN              NaN          NaN
# 5317                                NaN              NaN          NaN
# 5318                                NaN              NaN          NaN
# 5319                                NaN              NaN          NaN
# 5320                                NaN              NaN          NaN
# 5321                                NaN              NaN          NaN
# 5322                                NaN              NaN          NaN
# 5323                                NaN              NaN          NaN
# 5324                                NaN              NaN          NaN
# 5325                                NaN              NaN          NaN
# 5326                                NaN              NaN          NaN
# 5327                                NaN              NaN          NaN
#
#       contact_number confirmed_date released_date deceased_date     state
# 0               45.0     2020-01-20    2020-02-06           NaN  released
# 1               75.0     2020-01-24    2020-02-05           NaN  released
# 2               16.0     2020-01-26    2020-02-12           NaN  released
# 3               95.0     2020-01-27    2020-02-09           NaN  released
# 4               31.0     2020-01-30    2020-03-02           NaN  released
# 5               17.0     2020-01-30    2020-02-19           NaN  released
# 6                9.0     2020-01-30    2020-02-15           NaN  released
# 7              113.0     2020-01-31    2020-02-12           NaN  released
# 8                2.0     2020-01-31    2020-02-24           NaN  released
# 9               43.0     2020-01-31    2020-02-19           NaN  released
# 10               0.0     2020-01-31    2020-02-10           NaN  released
# 11             422.0     2020-02-01    2020-02-18           NaN  released
# 12               0.0     2020-02-02    2020-02-24           NaN  released
# 13               3.0     2020-02-02    2020-02-18           NaN  released
# 14              15.0     2020-02-02    2020-02-24           NaN  released
# 15             450.0     2020-02-04    2020-02-19           NaN  released
# 16             290.0     2020-02-05    2020-02-12           NaN  released
# 17               8.0     2020-02-05    2020-02-19           NaN  released
# 18              68.0     2020-02-05    2020-02-21           NaN  released
# 19               2.0     2020-02-05    2020-02-24           NaN  released
# 20               6.0     2020-02-05    2020-02-29           NaN  released
# 21               1.0     2020-02-06    2020-02-15           NaN  released
# 22              23.0     2020-02-06    2020-02-29           NaN  released
# 23               0.0     2020-02-06    2020-02-27           NaN  released
# 24              12.0     2020-02-09           NaN           NaN  isolated
# 25               0.0     2020-02-09           NaN           NaN  isolated
# 26              40.0     2020-02-09           NaN           NaN  isolated
# 27               1.0     2020-02-10    2020-02-17           NaN  released
# 28             117.0     2020-02-16           NaN           NaN  isolated
# 29              27.0     2020-02-16           NaN           NaN  isolated
# ...              ...            ...           ...           ...       ...
# 5298             NaN     2020-03-03           NaN           NaN  isolated
# 5299             NaN     2020-03-03           NaN           NaN  isolated
# 5300             NaN     2020-03-03           NaN           NaN  isolated
# 5301             NaN     2020-03-03           NaN           NaN  isolated
# 5302             NaN     2020-03-03           NaN           NaN  isolated
# 5303             NaN     2020-03-03           NaN           NaN  isolated
# 5304             NaN     2020-03-03           NaN           NaN  isolated
# 5305             NaN     2020-03-03           NaN           NaN  isolated
# 5306             NaN     2020-03-03           NaN           NaN  isolated
# 5307             NaN     2020-03-03           NaN           NaN  isolated
# 5308             NaN     2020-03-03           NaN           NaN  isolated
# 5309             NaN     2020-03-03           NaN           NaN  isolated
# 5310             NaN     2020-03-03           NaN           NaN  isolated
# 5311             NaN     2020-03-03           NaN           NaN  isolated
# 5312             NaN     2020-03-03           NaN           NaN  isolated
# 5313             NaN     2020-03-03           NaN           NaN  isolated
# 5314             NaN     2020-03-03           NaN           NaN  isolated
# 5315             NaN     2020-03-03           NaN           NaN  isolated
# 5316             NaN     2020-03-03           NaN           NaN  isolated
# 5317             NaN     2020-03-03           NaN           NaN  isolated
# 5318             NaN     2020-03-03           NaN           NaN  isolated
# 5319             NaN     2020-03-03           NaN           NaN  isolated
# 5320             NaN     2020-03-03           NaN           NaN  isolated
# 5321             NaN     2020-03-03           NaN           NaN  isolated
# 5322             NaN     2020-03-03           NaN           NaN  isolated
# 5323             NaN     2020-03-03           NaN           NaN  isolated
# 5324             NaN     2020-03-03           NaN           NaN  isolated
# 5325             NaN     2020-03-03           NaN           NaN  isolated
# 5326             NaN     2020-03-03           NaN           NaN  isolated
# 5327             NaN     2020-03-03           NaN           NaN  isolated
#
# [5328 rows x 14 columns]

# %%
df.describe()
# Out:
#                 id   birth_year  infection_order  infected_by  contact_number
# count  5328.000000   370.000000        35.000000    70.000000       47.000000
# mean   2664.500000  1973.589189         2.285714   379.000000       72.978723
# std    1538.205448    17.560546         1.405272   540.247528      188.155288
# min       1.000000  1932.000000         1.000000     3.000000        0.000000
# 25%    1332.750000  1960.000000         1.000000    29.250000        2.500000
# 50%    2664.500000  1974.000000         2.000000   126.000000       16.000000
# 75%    3996.250000  1987.750000         3.000000   563.250000       46.000000
# max    5328.000000  2018.000000         6.000000  2621.000000     1160.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5328 entries, 0 to 5327
# Data columns (total 14 columns):
# id                  5328 non-null int64
# sex                 383 non-null object
# birth_year          370 non-null float64
# country             5328 non-null object
# region              371 non-null object
# group               81 non-null object
# infection_reason    140 non-null object
# infection_order     35 non-null float64
# infected_by         70 non-null float64
# contact_number      47 non-null float64
# confirmed_date      5328 non-null object
# released_date       32 non-null object
# deceased_date       20 non-null object
# state               5328 non-null object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 582.8+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5328, step=1)

# %%
df.shape
# Out:
# (5328, 14)

# %%
df.columns
# Out:
# Index(['id', 'sex', 'birth_year', 'country', 'region', 'group',
#        'infection_reason', 'infection_order', 'infected_by', 'contact_number',
#        'confirmed_date', 'released_date', 'deceased_date', 'state'],
#       dtype='object')

# %%
df.count()
# Out:
# id                  5328
# sex                  383
# birth_year           370
# country             5328
# region               371
# group                 81
# infection_reason     140
# infection_order       35
# infected_by           70
# contact_number        47
# confirmed_date      5328
# released_date         32
# deceased_date         20
# state               5328
# dtype: int64

# %%
df.head()
# Out:
#    id     sex  birth_year country               region group infection_reason  \
# 0   1  female      1984.0   China  filtered at airport   NaN   visit to Wuhan
# 1   2    male      1964.0   Korea  filtered at airport   NaN   visit to Wuhan
# 2   3    male      1966.0   Korea         capital area   NaN   visit to Wuhan
# 3   4    male      1964.0   Korea         capital area   NaN   visit to Wuhan
# 4   5    male      1987.0   Korea         capital area   NaN   visit to Wuhan
#
#    infection_order  infected_by  contact_number confirmed_date released_date  \
# 0              1.0          NaN            45.0     2020-01-20    2020-02-06
# 1              1.0          NaN            75.0     2020-01-24    2020-02-05
# 2              1.0          NaN            16.0     2020-01-26    2020-02-12
# 3              1.0          NaN            95.0     2020-01-27    2020-02-09
# 4              1.0          NaN            31.0     2020-01-30    2020-03-02
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  released

# %%
df.tail()
# Out:
#         id  sex  birth_year country region group infection_reason  \
# 5323  5324  NaN         NaN   Korea    NaN   NaN              NaN
# 5324  5325  NaN         NaN   Korea    NaN   NaN              NaN
# 5325  5326  NaN         NaN   Korea    NaN   NaN              NaN
# 5326  5327  NaN         NaN   Korea    NaN   NaN              NaN
# 5327  5328  NaN         NaN   Korea    NaN   NaN              NaN
#
#       infection_order  infected_by  contact_number confirmed_date  \
# 5323              NaN          NaN             NaN     2020-03-03
# 5324              NaN          NaN             NaN     2020-03-03
# 5325              NaN          NaN             NaN     2020-03-03
# 5326              NaN          NaN             NaN     2020-03-03
# 5327              NaN          NaN             NaN     2020-03-03
#
#      released_date deceased_date     state
# 5323           NaN           NaN  isolated
# 5324           NaN           NaN  isolated
# 5325           NaN           NaN  isolated
# 5326           NaN           NaN  isolated
# 5327           NaN           NaN  isolated

# %%
df.isnull().sum()
# Out:
# id                     0
# sex                 4945
# birth_year          4958
# country                0
# region              4957
# group               5247
# infection_reason    5188
# infection_order     5293
# infected_by         5258
# contact_number      5281
# confirmed_date         0
# released_date       5296
# deceased_date       5308
# state                  0
# dtype: int64

# %%
df.sort_index()
# Out:
#         id     sex  birth_year country               region group  \
# 0        1  female      1984.0   China  filtered at airport   NaN
# 1        2    male      1964.0   Korea  filtered at airport   NaN
# 2        3    male      1966.0   Korea         capital area   NaN
# 3        4    male      1964.0   Korea         capital area   NaN
# 4        5    male      1987.0   Korea         capital area   NaN
# 5        6    male      1964.0   Korea         capital area   NaN
# 6        7    male      1991.0   Korea         capital area   NaN
# 7        8  female      1957.0   Korea         Jeollabuk-do   NaN
# 8        9  female      1992.0   Korea         capital area   NaN
# 9       10  female      1966.0   Korea         capital area   NaN
# 10      11    male      1995.0   Korea         capital area   NaN
# 11      12    male      1971.0   China         capital area   NaN
# 12      13    male      1992.0   Korea  filtered at airport   NaN
# 13      14  female      1980.0   China         capital area   NaN
# 14      15    male      1977.0   Korea         capital area   NaN
# 15      16  female      1977.0   Korea              Gwangju   NaN
# 16      17    male      1982.0   Korea         capital area   NaN
# 17      18  female      1999.0   Korea              Gwangju   NaN
# 18      19    male      1983.0   Korea         capital area   NaN
# 19      20  female      1978.0   Korea         capital area   NaN
# 20      21  female      1960.0   Korea         capital area   NaN
# 21      22    male      1973.0   Korea              Gwangju   NaN
# 22      23  female      1962.0   China         capital area   NaN
# 23      24    male      1992.0   Korea  filtered at airport   NaN
# 24      25  female      1946.0   Korea         capital area   NaN
# 25      26    male      1968.0   Korea         capital area   NaN
# 26      27  female      1982.0   China         capital area   NaN
# 27      28  female      1989.0   China         capital area   NaN
# 28      29    male      1938.0   Korea         capital area   NaN
# 29      30  female      1952.0   Korea         capital area   NaN
# ...    ...     ...         ...     ...                  ...   ...
# 5298  5299     NaN         NaN   Korea                  NaN   NaN
# 5299  5300     NaN         NaN   Korea                  NaN   NaN
# 5300  5301     NaN         NaN   Korea                  NaN   NaN
# 5301  5302     NaN         NaN   Korea                  NaN   NaN
# 5302  5303     NaN         NaN   Korea                  NaN   NaN
# 5303  5304     NaN         NaN   Korea                  NaN   NaN
# 5304  5305     NaN         NaN   Korea                  NaN   NaN
# 5305  5306     NaN         NaN   Korea                  NaN   NaN
# 5306  5307     NaN         NaN   Korea                  NaN   NaN
# 5307  5308     NaN         NaN   Korea                  NaN   NaN
# 5308  5309     NaN         NaN   Korea                  NaN   NaN
# 5309  5310     NaN         NaN   Korea                  NaN   NaN
# 5310  5311     NaN         NaN   Korea                  NaN   NaN
# 5311  5312     NaN         NaN   Korea                  NaN   NaN
# 5312  5313     NaN         NaN   Korea                  NaN   NaN
# 5313  5314     NaN         NaN   Korea                  NaN   NaN
# 5314  5315     NaN         NaN   Korea                  NaN   NaN
# 5315  5316     NaN         NaN   Korea                  NaN   NaN
# 5316  5317     NaN         NaN   Korea                  NaN   NaN
# 5317  5318     NaN         NaN   Korea                  NaN   NaN
# 5318  5319     NaN         NaN   Korea                  NaN   NaN
# 5319  5320     NaN         NaN   Korea                  NaN   NaN
# 5320  5321     NaN         NaN   Korea                  NaN   NaN
# 5321  5322     NaN         NaN   Korea                  NaN   NaN
# 5322  5323     NaN         NaN   Korea                  NaN   NaN
# 5323  5324     NaN         NaN   Korea                  NaN   NaN
# 5324  5325     NaN         NaN   Korea                  NaN   NaN
# 5325  5326     NaN         NaN   Korea                  NaN   NaN
# 5326  5327     NaN         NaN   Korea                  NaN   NaN
# 5327  5328     NaN         NaN   Korea                  NaN   NaN
#
#                        infection_reason  infection_order  infected_by  \
# 0                        visit to Wuhan              1.0          NaN
# 1                        visit to Wuhan              1.0          NaN
# 2                        visit to Wuhan              1.0          NaN
# 3                        visit to Wuhan              1.0          NaN
# 4                        visit to Wuhan              1.0          NaN
# 5                  contact with patient              2.0          3.0
# 6                        visit to Wuhan              1.0          NaN
# 7                        visit to Wuhan              1.0          NaN
# 8                  contact with patient              2.0          5.0
# 9                  contact with patient              3.0          6.0
# 10                 contact with patient              3.0          6.0
# 11        contact with patient in Japan              2.0          NaN
# 12                   residence in Wuhan              1.0          NaN
# 13                 contact with patient              3.0         12.0
# 14                 contact with patient              2.0          4.0
# 15                    visit to Thailand              1.0          NaN
# 16    contact with patient in Singapore              2.0          NaN
# 17                 contact with patient              2.0         16.0
# 18    contact with patient in Singapore              2.0          NaN
# 19                 contact with patient              3.0         15.0
# 20                 contact with patient              3.0          6.0
# 21                 contact with patient              2.0         16.0
# 22                       visit to Wuhan              1.0          NaN
# 23                   residence in Wuhan              1.0          NaN
# 24                 contact with patient              2.0         27.0
# 25                 contact with patient              1.0         27.0
# 26                       visit to China              1.0          NaN
# 27                 contact with patient              2.0          3.0
# 28                 contact with patient              4.0         83.0
# 29                 contact with patient              5.0         29.0
# ...                                 ...              ...          ...
# 5298                                NaN              NaN          NaN
# 5299                                NaN              NaN          NaN
# 5300                                NaN              NaN          NaN
# 5301                                NaN              NaN          NaN
# 5302                                NaN              NaN          NaN
# 5303                                NaN              NaN          NaN
# 5304                                NaN              NaN          NaN
# 5305                                NaN              NaN          NaN
# 5306                                NaN              NaN          NaN
# 5307                                NaN              NaN          NaN
# 5308                                NaN              NaN          NaN
# 5309                                NaN              NaN          NaN
# 5310                                NaN              NaN          NaN
# 5311                                NaN              NaN          NaN
# 5312                                NaN              NaN          NaN
# 5313                                NaN              NaN          NaN
# 5314                                NaN              NaN          NaN
# 5315                                NaN              NaN          NaN
# 5316                                NaN              NaN          NaN
# 5317                                NaN              NaN          NaN
# 5318                                NaN              NaN          NaN
# 5319                                NaN              NaN          NaN
# 5320                                NaN              NaN          NaN
# 5321                                NaN              NaN          NaN
# 5322                                NaN              NaN          NaN
# 5323                                NaN              NaN          NaN
# 5324                                NaN              NaN          NaN
# 5325                                NaN              NaN          NaN
# 5326                                NaN              NaN          NaN
# 5327                                NaN              NaN          NaN
#
#       contact_number confirmed_date released_date deceased_date     state
# 0               45.0     2020-01-20    2020-02-06           NaN  released
# 1               75.0     2020-01-24    2020-02-05           NaN  released
# 2               16.0     2020-01-26    2020-02-12           NaN  released
# 3               95.0     2020-01-27    2020-02-09           NaN  released
# 4               31.0     2020-01-30    2020-03-02           NaN  released
# 5               17.0     2020-01-30    2020-02-19           NaN  released
# 6                9.0     2020-01-30    2020-02-15           NaN  released
# 7              113.0     2020-01-31    2020-02-12           NaN  released
# 8                2.0     2020-01-31    2020-02-24           NaN  released
# 9               43.0     2020-01-31    2020-02-19           NaN  released
# 10               0.0     2020-01-31    2020-02-10           NaN  released
# 11             422.0     2020-02-01    2020-02-18           NaN  released
# 12               0.0     2020-02-02    2020-02-24           NaN  released
# 13               3.0     2020-02-02    2020-02-18           NaN  released
# 14              15.0     2020-02-02    2020-02-24           NaN  released
# 15             450.0     2020-02-04    2020-02-19           NaN  released
# 16             290.0     2020-02-05    2020-02-12           NaN  released
# 17               8.0     2020-02-05    2020-02-19           NaN  released
# 18              68.0     2020-02-05    2020-02-21           NaN  released
# 19               2.0     2020-02-05    2020-02-24           NaN  released
# 20               6.0     2020-02-05    2020-02-29           NaN  released
# 21               1.0     2020-02-06    2020-02-15           NaN  released
# 22              23.0     2020-02-06    2020-02-29           NaN  released
# 23               0.0     2020-02-06    2020-02-27           NaN  released
# 24              12.0     2020-02-09           NaN           NaN  isolated
# 25               0.0     2020-02-09           NaN           NaN  isolated
# 26              40.0     2020-02-09           NaN           NaN  isolated
# 27               1.0     2020-02-10    2020-02-17           NaN  released
# 28             117.0     2020-02-16           NaN           NaN  isolated
# 29              27.0     2020-02-16           NaN           NaN  isolated
# ...              ...            ...           ...           ...       ...
# 5298             NaN     2020-03-03           NaN           NaN  isolated
# 5299             NaN     2020-03-03           NaN           NaN  isolated
# 5300             NaN     2020-03-03           NaN           NaN  isolated
# 5301             NaN     2020-03-03           NaN           NaN  isolated
# 5302             NaN     2020-03-03           NaN           NaN  isolated
# 5303             NaN     2020-03-03           NaN           NaN  isolated
# 5304             NaN     2020-03-03           NaN           NaN  isolated
# 5305             NaN     2020-03-03           NaN           NaN  isolated
# 5306             NaN     2020-03-03           NaN           NaN  isolated
# 5307             NaN     2020-03-03           NaN           NaN  isolated
# 5308             NaN     2020-03-03           NaN           NaN  isolated
# 5309             NaN     2020-03-03           NaN           NaN  isolated
# 5310             NaN     2020-03-03           NaN           NaN  isolated
# 5311             NaN     2020-03-03           NaN           NaN  isolated
# 5312             NaN     2020-03-03           NaN           NaN  isolated
# 5313             NaN     2020-03-03           NaN           NaN  isolated
# 5314             NaN     2020-03-03           NaN           NaN  isolated
# 5315             NaN     2020-03-03           NaN           NaN  isolated
# 5316             NaN     2020-03-03           NaN           NaN  isolated
# 5317             NaN     2020-03-03           NaN           NaN  isolated
# 5318             NaN     2020-03-03           NaN           NaN  isolated
# 5319             NaN     2020-03-03           NaN           NaN  isolated
# 5320             NaN     2020-03-03           NaN           NaN  isolated
# 5321             NaN     2020-03-03           NaN           NaN  isolated
# 5322             NaN     2020-03-03           NaN           NaN  isolated
# 5323             NaN     2020-03-03           NaN           NaN  isolated
# 5324             NaN     2020-03-03           NaN           NaN  isolated
# 5325             NaN     2020-03-03           NaN           NaN  isolated
# 5326             NaN     2020-03-03           NaN           NaN  isolated
# 5327             NaN     2020-03-03           NaN           NaN  isolated
#
# [5328 rows x 14 columns]

# %%
df['sex'].value_counts()
# Out:
# female    194
# male      189
# Name: sex, dtype: int64

# %% [markdown]
# Applying Lambda function to change the sex from male and female to 1 and 0 respectively

# %%
df.sex = df.sex.apply(lambda X : 0 if X == 'female' else 1) 
df.head(5)
# Out:
#    id  sex  birth_year country               region group infection_reason  \
# 0   1    0      1984.0   China  filtered at airport   NaN   visit to Wuhan
# 1   2    1      1964.0   Korea  filtered at airport   NaN   visit to Wuhan
# 2   3    1      1966.0   Korea         capital area   NaN   visit to Wuhan
# 3   4    1      1964.0   Korea         capital area   NaN   visit to Wuhan
# 4   5    1      1987.0   Korea         capital area   NaN   visit to Wuhan
#
#    infection_order  infected_by  contact_number confirmed_date released_date  \
# 0              1.0          NaN            45.0     2020-01-20    2020-02-06
# 1              1.0          NaN            75.0     2020-01-24    2020-02-05
# 2              1.0          NaN            16.0     2020-01-26    2020-02-12
# 3              1.0          NaN            95.0     2020-01-27    2020-02-09
# 4              1.0          NaN            31.0     2020-01-30    2020-03-02
#
#   deceased_date     state
# 0           NaN  released
# 1           NaN  released
# 2           NaN  released
# 3           NaN  released
# 4           NaN  released

# %%
df.describe().T
# Out:
#                   count         mean          std     min      25%     50%  \
# id               5328.0  2664.500000  1538.205448     1.0  1332.75  2664.5
# sex              5328.0     0.963589     0.187329     0.0     1.00     1.0
# birth_year        370.0  1973.589189    17.560546  1932.0  1960.00  1974.0
# infection_order    35.0     2.285714     1.405272     1.0     1.00     2.0
# infected_by        70.0   379.000000   540.247528     3.0    29.25   126.0
# contact_number     47.0    72.978723   188.155288     0.0     2.50    16.0
#
#                      75%     max
# id               3996.25  5328.0
# sex                 1.00     1.0
# birth_year       1987.75  2018.0
# infection_order     3.00     6.0
# infected_by       563.25  2621.0
# contact_number     46.00  1160.0

# %% [markdown]
# # **Data Visualization**

# %%
sns.heatmap(df.isnull(), yticklabels = False)
#checking NULl Values via graph,where you can find yellow colour which means that column contains NUll values

# %%
#sns.set(rc={'figure.figsize':(10,8)})

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df['region'],).set_title('Regions affected Overall') # Ploting graph which regions maximum number of affected peole
# Out:
# Text(0.5, 1.0, 'Regions affected Overall')

# %%
sns.countplot(x='sex',data=df, hue='sex')

# %% [markdown]
# Which country have maximum number of affected people

# %%
sns.countplot(x='country',data=df, hue='country')

# %% [markdown]
#
# Ploting Graph which area maximum number of affected people in country.

# %%
sns.countplot(y='group',data=df, hue='country')

# %%
sns.countplot(y='group',data=df, hue='group');

# %% [markdown]
# Confirmed Patients

# %%
plt.figure(figsize=(10,8))
sns.countplot(y='group',data=df, hue='confirmed_date');

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='country',data=df, hue='confirmed_date');

# %% [markdown]
# Ploting the graph confirmed date of the human infected or not in the Korea Country

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df['confirmed_date'].loc[(df['country']=="Korea")],).set_title('Confirmed dates in Korea')
# Out:
# Text(0.5, 1.0, 'Confirmed dates in Korea')

# %% [markdown]
# Ploting the graph confirmed date of the human infected or not in the China Country

# %%
plt.figure(figsize=(20,15))
sns.countplot(y=df['confirmed_date'].loc[(df['country']=="China")],).set_title('Confirmed dates in China')
# Out:
# Text(0.5, 1.0, 'Confirmed dates in China')

# %% [markdown]
# Ploting the graph confirmed date of the human infected or not in the Mongloia Country

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['confirmed_date'].loc[(df['country']=="Mongolia")],).set_title('Confirmed dates in Mongloia')
# Out:
# Text(0.5, 1.0, 'Confirmed dates in Mongloia')

# %%
plt.figure(figsize=(10,6))
sns.stripplot(x=df.country, y=df.sex, hue=df.sex)
plt.title("Age of patients from different countries")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='region',data=df, hue='confirmed_date');

# %%
confirmed_patients_series = df['confirmed_date'].value_counts().sort_index()

confirmed_patients_series.cumsum().plot(legend='accumulated')
confirmed_patients_series.plot(kind='bar', color='orange', legend='daily', figsize=(16, 5), grid=True)

# %%
limit_series = confirmed_patients_series[:df[df['id'] == 31]['confirmed_date'].values[0]]
limit_series.cumsum().plot(legend='accumulated')
limit_series.plot(kind='bar', color='orange', legend='daily', figsize=(16, 5), grid=True)

# %%
limit_series = confirmed_patients_series[df[df['id'] == 31]['confirmed_date'].values[0]:]
limit_series.cumsum().plot(legend='accumulated')
limit_series.plot(kind='bar', color='orange', legend='daily', figsize=(16, 5), grid=True)

# %%
sns.countplot(x=df['state'].loc[(df['infection_reason']=='contact with patient')])

# %% [markdown]
# ## Great Work Done !!
#
# **VenkataNarayana Bommanaboina**
#
# LinkedIn- https://www.linkedin.com/in/bvnarayana515739
#
# Github- https://github.com/venkatanarayana143
#
# E-mail- bvnarayana515739@gmail.com
